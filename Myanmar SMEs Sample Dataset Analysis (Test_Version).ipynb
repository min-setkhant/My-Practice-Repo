# %% [markdown]
# 📒 Myanmar SMEs Sample Dataset Analysis (Test_Version)
# 1. Introduction
#
# This notebook explores and analyzes the Myanmar SMEs dataset.
# We will:
#
# Load and inspect the dataset
#
# Check data quality (missing values, duplicates, column types)
#
# Clean and preprocess data
#
# Perform exploratory analysis
#
# Visualize some interesting insights

# %%
# Core Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# For Visululization We need the following packages
# **matplotlib.pyplot**
# **seaborn**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# To get the better visuals we will use these
# plt.style.use("seaborn-v0_8")
# sns.set_palette("Set2")

# %%
# Settings for better visuals
plt.style.use("seaborn-v0_8")
sns.set_palette("Set2")

# %% [markdown]
# Now Let's see the Myanmar SMEs dataset

# %%
# Load CSV file
file_path = "Myanmar SMEs Listsed.csv"  # update path if needed
df = pd.read_csv(file_path)

# Display basic info
df.head()
# Out:
#    Business ID        Business Name  Industry Sector Owner Name  Gender  \
# 0            1  Aye Myanmar Trading           Retail    Aye Aye  Female
# 1            2       Golden Harvest      Agriculture    Tun Tun    Male
# 2            3         Shwe Min Co.    Manufacturing    Min Min    Male
# 3            4      Evergreen Foods  Food Processing    Hla Hla  Female
# 4            5         Royal Rubber           Rubber    Soe Moe    Male
#
#   Position Contact Number    Email Address Region or State Business Size  \
# 0    Owner   09-123456789  aye@example.com          Yangon         Small
# 1  Manager   09-987654321  tun@example.com        Mandalay        Medium
# 2    Owner   09-234567890  min@example.com            Bago         Small
# 3    Owner   09-345678901  hla@example.com          Yangon        Medium
# 4  Manager   09-456789012  soe@example.com             Mon         Micro
#
#   Registration Status  Number of Employees  Revenue (Annual) Customer Base  \
# 0          Registered                   15             50000  Retail Shops
# 1      Not Registered                   50            200000       Farmers
# 2          Registered                   10             30000   Wholesalers
# 3      Not Registered                   30            150000  Supermarkets
# 4          Registered                    5             10000     Exporters
#
#   Social Media Presence
# 0                   Yes
# 1                    No
# 2                   Yes
# 3                    No
# 4                   Yes

# %% [markdown]
# Now is time to basic dataset information get to know

# %%
# Shape
print("Rows, Columns:", df.shape)

# Info (column types, nulls, etc.)
df.info()

# Summary statistics
df.describe(include="all").T
# Out:
# Rows, Columns: (20, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Business ID            20 non-null     int64
#  1   Business Name          20 non-null     object
#  2   Industry Sector        20 non-null     object
#  3   Owner Name             20 non-null     object
#  4   Gender                 18 non-null     object
#  5   Position               20 non-null     object
#  6   Contact Number         20 non-null     object
#  7   Email Address          19 non-null     object
#  8   Region or State        20 non-null     object
#  9   Business Size          20 non-null     object
#  10  Registration Status    20 non-null     object
#  11  Number of Employees    20 non-null     int64
#  12  Revenue (Annual)       20 non-null     int64
#  13  Customer Base          20 non-null     object
#  14  Social Media Presence  20 non-null     object
# dtypes: int64(3), object(12)
# memory usage: 2.5+ KB
#                       count unique                  top freq     mean  \
# Business ID            20.0    NaN                  NaN  NaN     10.5
# Business Name            20     11  Aye Myanmar Trading    2      NaN
# Industry Sector          20      9          Agriculture    4      NaN
# Owner Name               20     10              Aye Aye    2      NaN
# Gender                   18      2               Female    9      NaN
# Position                 20      2                Owner   12      NaN
# Contact Number           20     10         09-123456789    2      NaN
# Email Address            19     10      aye@example.com    2      NaN
# Region or State          20      7               Yangon    6      NaN
# Business Size            20      3                Small    8      NaN
# Registration Status      20      2           Registered   12      NaN
# Number of Employees    20.0    NaN                  NaN  NaN     21.8
# Revenue (Annual)       20.0    NaN                  NaN  NaN  86300.0
# Customer Base            20     10         Retail Shops    2      NaN
# Social Media Presence    20      2                  Yes   12      NaN
#
#                                 std     min      25%      50%       75%  \
# Business ID                 5.91608     1.0     5.75     10.5     15.25
# Business Name                   NaN     NaN      NaN      NaN       NaN
# Industry Sector                 NaN     NaN      NaN      NaN       NaN
# Owner Name                      NaN     NaN      NaN      NaN       NaN
# Gender                          NaN     NaN      NaN      NaN       NaN
# Position                        NaN     NaN      NaN      NaN       NaN
# Contact Number                  NaN     NaN      NaN      NaN       NaN
# Email Address                   NaN     NaN      NaN      NaN       NaN
# Region or State                 NaN     NaN      NaN      NaN       NaN
# Business Size                   NaN     NaN      NaN      NaN       NaN
# Registration Status             NaN     NaN      NaN      NaN       NaN
# Number of Employees       15.312877     5.0     10.0     17.5      30.0
# Revenue (Annual)       69291.223717  8000.0  30000.0  62500.0  150000.0
# Customer Base                   NaN     NaN      NaN      NaN       NaN
# Social Media Presence           NaN     NaN      NaN      NaN       NaN
#
#                             max
# Business ID                20.0
# Business Name               NaN
# Industry Sector             NaN
# Owner Name                  NaN
# Gender                      NaN
# Position                    NaN
# Contact Number              NaN
# Email Address               NaN
# Region or State             NaN
# Business Size               NaN
# Registration Status         NaN
# Number of Employees        50.0
# Revenue (Annual)       200000.0
# Customer Base               NaN
# Social Media Presence       NaN

# %% [markdown]
# Now is time to Data Cleaning

# %%
# Check missing values
print("Missing values per column:")
print(df.isnull().sum())

# Drop duplicates if any
df = df.drop_duplicates()

# Handle missing values (example: fill with 'Unknown' for categorical, mean for numeric)
for col in df.columns:
    if df[col].dtype == "object":
        df[col] = df[col].fillna("Unknown")
    else:
        df[col] = df[col].fillna(df[col].mean())

print("After cleaning:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Business ID              0
# Business Name            0
# Industry Sector          0
# Owner Name               0
# Gender                   2
# Position                 0
# Contact Number           0
# Email Address            1
# Region or State          0
# Business Size            0
# Registration Status      0
# Number of Employees      0
# Revenue (Annual)         0
# Customer Base            0
# Social Media Presence    0
# dtype: int64
# After cleaning:
# Business ID              0
# Business Name            0
# Industry Sector          0
# Owner Name               0
# Gender                   0
# Position                 0
# Contact Number           0
# Email Address            0
# Region or State          0
# Business Size            0
# Registration Status      0
# Number of Employees      0
# Revenue (Annual)         0
# Customer Base            0
# Social Media Presence    0
# dtype: int64

# %% [markdown]
# 6. Exploratory Data Analysis (EDA)
# 6.1 Distribution of SMEs by Region/State

# %%
if "Business Type" in df.columns:
    plt.figure(figsize=(12,6))
    sns.countplot(data=df, x="Business Type", order=df["Business Type"].value_counts().index)
    plt.xticks(rotation=45)
    plt.title("Distribution of SMEs by Business Type")
    plt.show()

# %% [markdown]
# Now is time for you dude!!!
